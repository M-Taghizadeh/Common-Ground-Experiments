# %% [markdown]
# # Fine-tune FLAN-T5 for Event Generation
# In this code, you will see how to fine-tune [google/flan-t5-base](https://huggingface.co/google/flan-t5-base) for event generation task using Hugging Face Transformers. Flan t5 is created based on the T5 language model. For the same number of parameters, these models have been fine-tuned on more than 1000 additional tasks covering also more languages.
#
# You will learn how to:
#
# 1. [Install requirements](#1-install-requirements)
# 2. [Load Corpus](#2-load-and-prepare-samsum-dataset)
# 3. [Fine-tune and evaluate FLAN-T5](#3-fine-tune-and-evaluate-flan-t5)
# 4. [Run Inference](#4-run-inference)
#
# ## FLAN-T5
# FLAN-T5 released with the [Scaling Instruction-Finetuned Language Models](https://arxiv.org/pdf/2210.11416.pdf) paper is an enhanced version of T5 that has been finetuned in a mixture of tasks. The paper explores instruction finetuning with a particular focus on (1) scaling the number of tasks, (2) scaling the model size, and (3) finetuning on chain-of-thought data. The paper discovers that overall instruction finetuning is a general method for improving the performance and usability of pretrained language models.

# %% [markdown]
# ## 1. Install requirements
#
# Our first step is to install the Hugging Face Libraries, including transformers and datasets. Running the following cell will install all the required packages.

# %%
# python
# !pip install pytesseract transformers==4.28.1 datasets evaluate rouge-score sentence_transformers nltk tensorboard py7zr --upgrade

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %% [markdown]
# ## Connect to Drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import glob
from datasets import load_dataset
import datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Load Corpus

# %%
import pickle

f = open("/content/drive/MyDrive/Corpus/CG_Corpus/event_extraction_3to1_2previous.dat", "rb")
dataset = pickle.load(f)
f.close()

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Utterance', 'Sentence', 'Events'],
#         num_rows: 415
#     })
#     test: Dataset({
#         features: ['Utterance', 'Sentence', 'Events'],
#         num_rows: 146
#     })
# })

# %%
dataset['train'][65]
# Out:
# {'Utterance': 'B: You know? Now things are just like kind of mellow and I’m just n- you know wrapping things up so it’s not that bad.  ',
#  'Sentence': 'B: You know? Now things are just like kind of mellow and I’m just n- you know wrapping things up so it’s not that bad.  \nContext:\nutterance1: A: The kid sister thing? \nutterance2: B: Well no. Not really that but it’s been really busy as far as work is concerned.  \n',
#  'Events': "Event1: Now things are like kind of mellow\nEvent2: B is just wrapping things up so B' situation is not that bad\nEvent3: B is just wrapping things up\nEvent4: B's situation is not that bad\n"}

# %%
from random import randrange


sample = dataset['train'][randrange(len(dataset["train"]))]
print(f"Utterance: \n{sample['Utterance']}\n---------------")
print(f"Sentence: \n{sample['Sentence']}\n---------------")
print(f"Events: \n{sample['Events']}\n---------------")
# Out:
# Utterance:
# B: oh yeah and then there was this friend I had she was eight and a half months pregnant and you know {breath} baby had a cord accident and she died. [[said laughing]]
# ---------------
# Sentence:
# B: oh yeah and then there was this friend I had she was eight and a half months pregnant and you know {breath} baby had a cord accident and she died. [[said laughing]]
# Context:
# utterance1: A: yeah ((I’m still here)) [distortion]
# utterance2: B: oh so I had so I talked to my doctor about it and apparently it’s very rare [[said laughing]] so don’t ask me why I’ve heard so many stories about it but {sniff}
#
# ---------------
# Events:
# Event1: There was B's friend that B had
# Event2: B had a friend
# Event3: B's friend was eight and a half months pregnant
# Event4: B's friend's baby had a cord accident
# Event5: B's friend's baby died
#
# ---------------

# %% [markdown]
# Tokenizer

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_id="google/flan-t5-base"

# Load tokenizer of FLAN-t5-base
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %% [markdown]
# text2text-generation task: our model will take a utterance as input and generate events as output. For this we want to understand how long our input and output will be to be able to efficiently batch our data.

# %%
from datasets import concatenate_datasets

# The maximum total input sequence length after tokenization.
# Sequences longer than this will be truncated, sequences shorter will be padded.
tokenized_inputs = concatenate_datasets([dataset["train"], dataset["test"]]).map(lambda x: tokenizer(x["Sentence"], truncation=True), batched=True, remove_columns=['Utterance', 'Sentence', 'Events'])
max_source_length = max([len(x) for x in tokenized_inputs["input_ids"]])
print(f"Max source length: {max_source_length}")

# The maximum total sequence length for target text after tokenization.
# Sequences longer than this will be truncated, sequences shorter will be padded."
tokenized_targets = concatenate_datasets([dataset["train"], dataset["test"]]).map(lambda x: tokenizer(x["Events"], truncation=True), batched=True, remove_columns=['Utterance', 'Sentence', 'Events'])
max_target_length = max([len(x) for x in tokenized_targets["input_ids"]])
print(f"Max target length: {max_target_length}")
# Out:
# Map:   0%|          | 0/561 [00:00<?, ? examples/s]
# Max source length: 209
# Map:   0%|          | 0/561 [00:00<?, ? examples/s]
# Max target length: 252

# %%
def preprocess_function(sample,padding="max_length"):
    # add prefix to the input for t5
    inputs = ["Events: " + item for item in sample["Sentence"]]

    # tokenize inputs
    model_inputs = tokenizer(inputs, max_length=max_source_length, padding=padding, truncation=True)

    # Tokenize targets with the `text_target` keyword argument
    labels = tokenizer(text_target=sample["Events"], max_length=max_target_length, padding=padding, truncation=True)

    # If we are padding here, replace all tokenizer.pad_token_id in the labels by -100 when we want to ignore
    # padding in the loss.
    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
        ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess_function, batched=True, remove_columns=['Utterance', 'Sentence', 'Events'])
print(f"Keys of tokenized dataset: {list(tokenized_dataset['train'].features)}")
# Out:
# Map:   0%|          | 0/415 [00:00<?, ? examples/s]
# Map:   0%|          | 0/146 [00:00<?, ? examples/s]
# Keys of tokenized dataset: ['input_ids', 'attention_mask', 'labels']

# %% [markdown]
# ## 3. Fine-tune and evaluate FLAN-T5

# %%
from transformers import AutoModelForSeq2SeqLM

# huggingface hub model id
model_id="google/flan-t5-base"

# load model from the hub
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# Trainer: We are going to use evaluate library to evaluate the rogue score.
#
# We are going to use `evaluate` library to evaluate the `rogue` score.

# %%
import evaluate
import nltk
import numpy as np
from nltk.tokenize import sent_tokenize
nltk.download("punkt")

# Metric
metric = evaluate.load("rouge")

# helper function to postprocess text
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    # rougeLSum expects newline after each sentence
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    return result
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %% [markdown]
# Before we can start training is to create a `DataCollator` that will take care of padding our inputs and labels. We will use the `DataCollatorForSeq2Seq` from the 🤗 Transformers library.

# %%
from transformers import DataCollatorForSeq2Seq

# we want to ignore tokenizer pad token in the loss
label_pad_token_id = -100
# Data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=8
)

# %% [markdown]
# The last step is to define the hyperparameters (`TrainingArguments`) we want to use for our training. We are leveraging the [Hugging Face Hub](https://huggingface.co/models) integration of the `Trainer` to automatically push our checkpoints, logs and metrics during training into a repository.

# %%
from huggingface_hub import HfFolder
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# Hugging Face repository id
repository_id = f"{model_id.split('/')[1]}-event-extraction-train-on-3-test-on-1new"

# Define training args
training_args = Seq2SeqTrainingArguments(
    output_dir=repository_id,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    fp16=False, # Overflows with fp16
    learning_rate=5e-5,
    num_train_epochs=16,
    # logging & evaluation strategies
    # logging_dir=f"{repository_id}/logs",
    logging_strategy="epoch",
    # logging_steps=100,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=False,
    # metric_for_best_model="overall_f1",
    # push to hub parameters
    report_to="tensorboard",
    push_to_hub=False,
    hub_strategy="every_save",
    # hub_model_id=repository_id,
    hub_token=HfFolder.get_token(),
)

# Create Trainer instance
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    compute_metrics=compute_metrics,
)

# %% [markdown]
# We can start our training by using the `train` method of the `Trainer`.

# %%
# Start training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='832' max='832' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [832/832 21:24, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.792900</td>
#       <td>1.035845</td>
#       <td>40.596400</td>
#       <td>23.219200</td>
#       <td>38.611200</td>
#       <td>38.549200</td>
#       <td>17.808219</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.232200</td>
#       <td>0.954675</td>
#       <td>45.946000</td>
#       <td>28.527400</td>
#       <td>43.636000</td>
#       <td>43.696300</td>
#       <td>16.712329</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.049400</td>
#       <td>0.934071</td>
#       <td>47.471500</td>
#       <td>30.205600</td>
#       <td>45.442200</td>
#       <td>45.244700</td>
#       <td>17.328767</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.943800</td>
#       <td>0.929355</td>
#       <td>47.220900</td>
#       <td>29.536400</td>
#       <td>44.914300</td>
#       <td>44.824200</td>
#       <td>17.136986</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.860800</td>
#       <td>0.930644</td>
#       <td>47.006400</td>
#       <td>30.051300</td>
#       <td>44.946900</td>
#       <td>44.934500</td>
#       <td>17.061644</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.794300</td>
#       <td>0.934780</td>
#       <td>47.904600</td>
#       <td>30.620700</td>
#       <td>45.836300</td>
#       <td>45.861400</td>
#       <td>16.767123</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.751900</td>
#       <td>0.951528</td>
#       <td>47.755300</td>
#       <td>30.743300</td>
#       <td>45.896500</td>
#       <td>45.952000</td>
#       <td>16.808219</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.699900</td>
#       <td>0.960778</td>
#       <td>48.208200</td>
#       <td>31.840100</td>
#       <td>46.756600</td>
#       <td>46.714000</td>
#       <td>16.575342</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.661300</td>
#       <td>0.959035</td>
#       <td>47.897300</td>
#       <td>32.253600</td>
#       <td>46.408000</td>
#       <td>46.405200</td>
#       <td>16.500000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.639800</td>
#       <td>0.963861</td>
#       <td>48.885600</td>
#       <td>32.830900</td>
#       <td>47.358900</td>
#       <td>47.285200</td>
#       <td>16.609589</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.610500</td>
#       <td>0.981355</td>
#       <td>48.797400</td>
#       <td>32.718800</td>
#       <td>47.081800</td>
#       <td>47.042500</td>
#       <td>16.671233</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.594400</td>
#       <td>0.983414</td>
#       <td>49.421500</td>
#       <td>33.264100</td>
#       <td>47.732200</td>
#       <td>47.700700</td>
#       <td>16.657534</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.574000</td>
#       <td>0.988627</td>
#       <td>48.895600</td>
#       <td>32.489900</td>
#       <td>47.343100</td>
#       <td>47.194100</td>
#       <td>16.541096</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.554100</td>
#       <td>1.001760</td>
#       <td>48.803300</td>
#       <td>32.418800</td>
#       <td>46.920000</td>
#       <td>46.849700</td>
#       <td>16.746575</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.552300</td>
#       <td>1.001940</td>
#       <td>48.507600</td>
#       <td>32.154400</td>
#       <td>46.901800</td>
#       <td>46.782800</td>
#       <td>16.636986</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.556800</td>
#       <td>1.001645</td>
#       <td>48.418800</td>
#       <td>32.049700</td>
#       <td>46.684800</td>
#       <td>46.543400</td>
#       <td>16.712329</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=832, training_loss=0.804275916172908, metrics={'train_runtime': 1288.2623, 'train_samples_per_second': 5.154, 'train_steps_per_second': 0.646, 'total_flos': 1918176533544960.0, 'train_loss': 0.804275916172908, 'epoch': 16.0})

# %% [markdown]
# Nice, we have trained our model. 🎉 Lets run evaluate the best model again on the test set.

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='19' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [19/19 00:13]
#     </div>
# {'eval_loss': 1.0016454458236694,
#  'eval_rouge1': 48.4188,
#  'eval_rouge2': 32.0497,
#  'eval_rougeL': 46.6848,
#  'eval_rougeLsum': 46.5434,
#  'eval_gen_len': 16.71232876712329,
#  'eval_runtime': 15.4396,
#  'eval_samples_per_second': 9.456,
#  'eval_steps_per_second': 1.231,
#  'epoch': 16.0}

# %%
# # Save our tokenizer and create model card
# tokenizer.save_pretrained(repository_id)
# trainer.create_model_card()
# # Push the results to the hub
# trainer.push_to_hub()

# %% [markdown]
# ## Test And Evaluate on Rouge and SBERT

# %% [markdown]
# ### Rouge Score

# %%
from rouge_score import rouge_scorer

def calculate_rouge_score(reference, candidate):
  scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL', ], use_stemmer=True)
  scores = scorer.score(reference, candidate)
  return scores['rougeL']

# %%
samples_number = len(dataset['test'])

SUM = 0
for sample in dataset['test']:
  TEXT = "Events: " + sample['Sentence']
  ground_truth = sample['Events']
  inputs = tokenizer(TEXT, return_tensors="pt").to('cuda')
  outputs = model.generate(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"], max_length=512)
  prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
  rouge = calculate_rouge_score(ground_truth, prediction)
  SUM += rouge[2] # rougeL fmeasure

rouge_avg = SUM/samples_number
print(f"\nRougeL average on test set with {samples_number} samples: {rouge_avg}")
# Out:
# RougeL average on test set with 146 samples: 0.49606980470316664

# %% [markdown]
# ### SBERT Score

# %%
from sentence_transformers import SentenceTransformer, util

sbert_model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
from sentence_transformers import SentenceTransformer, util
import torch

def calculate_sbert_score(sentences1, sentences2):
    # Compute embedding for both lists
    embeddings1 = sbert_model.encode(sentences1, convert_to_tensor=True)
    embeddings2 = sbert_model.encode(sentences2, convert_to_tensor=True)

    # ompute cosine-similarities
    cosine_scores = util.cos_sim(embeddings1, embeddings2)
    output = torch.tensor([cosine_scores])
    return round(output.item(), 4)

# %%
samples_number = len(dataset['test'])

SUM = 0
for sample in dataset['test']:
  TEXT = "Events: " + sample['Sentence']
  ground_truth = sample['Events']
  inputs = tokenizer(TEXT, return_tensors="pt").to('cuda')
  outputs = model.generate(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"], max_length=512)
  prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
  sbert_score = calculate_sbert_score(ground_truth, prediction)
  SUM += sbert_score

  if sbert_score<0.2: print(f"\n[-] Sentence:{TEXT} \nground_truth: {ground_truth} \nprediction: {prediction} \nsimilarity score: {sbert_score}", '\n------------------------------')
  if sbert_score>0.9: print(f"\n[+] Sentence:{TEXT} \nground_truth: {ground_truth} \nprediction: {prediction} \nsimilarity score: {sbert_score}", '\n------------------------------')

sbert_score_avg = SUM/samples_number
print(f"\n\n\nSBERT Score Cosine Similarity Average on test set with {samples_number} samples: {sbert_score_avg}")
# Out:
# [+] Sentence:Events: B: %um I took them to %uh &Jill’s and they spent two days there and I guess she couldn’t take them and their mom and dad came.
# Context:
#
# ground_truth: Event1: B took the kids to Jill's
# Event2: The kids spent two days at Jill's
# Event3: B guesses Jill couldn't take the kids
# Event4: Jill couldn't take the kids
# Event5: The kid's mom and dad came
#
# prediction: Event1: B took the children to Jill's Event2: The children spent two days at Jill's Event3: B guesses Jill couldn't take the children Event4: The children's mom and dad came Event5: B took the children to Jill's Event6: The children spent two days at Jill's Event7: B guesses Jill couldn't take the children Event8: The children's mom and dad came Event9: The children's mom and dad came Event10: The children's mom and dad came Event11: The children's mom and dad came Event12: The children's mom and dad came Event13: The children's mom and dad came Event14: The children's mom and dad came Event15: The children's mom and dad came Event16: The children's mom and dad came Event17: The children's mom and dad came Event18: The children's mom and dad came
# similarity score: 0.9135
# ------------------------------
#
# [+] Sentence:Events: B: yeah.
# Context:
# utterance1: B: %um I took them to %uh &Jill’s and they spent two days there and I guess she couldn’t take them and their mom and dad came.
# utterance2: A: You mean at te- in &Texas?
#
# ground_truth: Event1: B says yeah.
#
# prediction: Event1: B says yeah.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: And their mom and dad drove down there and got them.
# Context:
# utterance1: A: You mean at te- in &Texas?
# utterance2: B: yeah.
#
# ground_truth: Event1: The kids' mom and dad drove down to Texas
# Event2: The kids' mom and dad got the kids from Texas
#
# prediction: Event1: B's friends's mom and dad drove down to Texas Event2: B's friends's mom and dad got the kids
# similarity score: 0.9108
# ------------------------------
#
# [+] Sentence:Events: A: Did she have her baby yet?
# Context:
# utterance1: A: Darn it. I thought I was going to get to see everybody.
# utterance2: B: come back like a while ago but &Jill like she keeps farting around and won’t want to go get them and
#
# ground_truth: Event1: A asks B if Jill had her baby yet
# Event2: Jill had her baby yet
#
# prediction: Event1: A asks B if Jill has Jill's baby yet Event2: Jill has Jill's baby
# similarity score: 0.9415
# ------------------------------
#
# [+] Sentence:Events: A: What kind of car do you have?
# Context:
# utterance1: A: Go get them.
# utterance2: B: You know I was gone
#
# ground_truth: Event1: A asks B what kind of car B has
# Event2: B has a car
#
# prediction: Event1: A asks B what kind of car B has Event2: B has a car
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: Same car.
# Context:
# utterance1: A: What kind of car do you have?
# utterance2: A: What kind of car do you have now?
#
# ground_truth: Event1: B has the same car
#
# prediction: Event1: B says Same car
# similarity score: 0.9378
# ------------------------------
#
# [+] Sentence:Events: B: yeah.
# Context:
# utterance1: B: Same car.
# utterance2: A: oh. really? You got that thing repaired?
#
# ground_truth: Event1: B says yeah.
#
# prediction: Event1: B says yeah.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: yeah. I work ten at night to six in the morning. &Bo &Bo’s happy because %uh he don’t have to go back to day care.
# Context:
# utterance1: B: yeah.
# utterance2: A: What else is going on? You’re busy with work and
#
# ground_truth: Event1: B works ten at night to six in the morning
# Event2: Bo's happy because Bo doesn't have to go back to day care
# Event3: Bo's happy
# Event4: Bo doesn't have to go back to day care
#
# prediction: Event1: B works ten at night to six in the morning Event2: Bo is happy because Bo's baby doesn't have to go back to day care Event3: Bo's baby doesn't have to go back to day care
# similarity score: 0.9678
# ------------------------------
#
# [+] Sentence:Events: A: Right. When do you sleep then?
# Context:
# utterance1: A: What else is going on? You’re busy with work and
# utterance2: B: yeah. I work ten at night to six in the morning. &Bo &Bo’s happy because %uh he don’t have to go back to day care.
#
# ground_truth: Event1: A asks B when B sleeps then
# Event2: B sleeps
#
# prediction: Event1: A asks B when do B and Bo sleep Event2: B and Bo sleep
# similarity score: 0.9121
# ------------------------------
#
# [+] Sentence:Events: B: I p- I sleep probably a couple hours in the morning and then like at nap time.
# Context:
# utterance1: B: yeah. I work ten at night to six in the morning. &Bo &Bo’s happy because %uh he don’t have to go back to day care.
# utterance2: A: Right. When do you sleep then?
#
# ground_truth: Event1: B sleeps probably a couple hours in the morning
# Event2: Then B sleeps probably like at nap time
#
# prediction: Event1: B sleeps probably a couple hours in the morning Event2: B sleeps probably a couple hours in the morning Event3: B sleeps probably a couple hours in the morning Event4: B sleeps probably a couple hours in the morning Event5: B sleeps probably a couple hours in the morning
# similarity score: 0.9136
# ------------------------------
#
# [+] Sentence:Events: A: yeah. You never did require much sleep.
# Context:
# utterance1: A: Right. When do you sleep then?
# utterance2: B: I p- I sleep probably a couple hours in the morning and then like at nap time.
#
# ground_truth: Event1: B never required much sleep
#
# prediction: Event1: B never did require much sleep
# similarity score: 0.9852
# ------------------------------
#
# [+] Sentence:Events: A: {breath} So has, has %uh the old man and the old lady called you lately?
# Context:
# utterance1: B: I p- I sleep probably a couple hours in the morning and then like at nap time.
# utterance2: A: yeah. You never did require much sleep.
#
# ground_truth: Event1: A asks B if the old man and the old lady called B lately
# Event2: The old man and the old lady called B lately
#
# prediction: Event1: A asks B if the old man and the old lady called B lately Event2: The old man and the old lady called B lately
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: Ain’t worried about it.
# Context:
# utterance1: A: {breath} So has, has %uh the old man and the old lady called you lately?
# utterance2: B: No.
#
# ground_truth: Event1: B ain't worried about the old man and the old lady not calling B
#
# prediction: Event1: Ain't worried about the old man and the old lady calling B lately
# similarity score: 0.9512
# ------------------------------
#
# [+] Sentence:Events: A: yeah.
# Context:
# utterance1: A: in &Illinois recently.
# utterance2: B: She was?
#
# ground_truth: Event1: A says yeah.
#
# prediction: Event1: A says yeah.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: No.
# Context:
# utterance1: A: -- out of her house.
# utterance2: B: yeah. Well &Jill’s been getting the shit beat out of her and all that at
#
# ground_truth: Event1: B says No.
#
# prediction: Event1: B says No.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: A: And I said no &Kara you have to do what’s right for &Kara.
# Context:
# utterance1: A: {lipsmack} {breath} &uh, and this sounded just like something like %uh her mother-in-law or w- I don’t know th- what the hell relationsh- it wouldn’t be mother-in-law.
# utterance2: A: probably is saying to her. {breath} &Kara says well I have to do what’s right for &David. [[imitating Kara in last nine words]]
#
# ground_truth: Event1: A said that Kara doesn't have to do what's right for David
# Event2: Kara doesn't have to do what's right for David
# Event3: A said that Kara has to do what's right for Kara
# Event4: Kara has to do what's right for Kara
#
# prediction: Event1: A said no David has to do what's right for Kara Event2: David has to do what's right for Kara
# similarity score: 0.9085
# ------------------------------
#
# [+] Sentence:Events: A: And what’s right for &Kara will be right for &David.
# Context:
# utterance1: A: probably is saying to her. {breath} &Kara says well I have to do what’s right for &David. [[imitating Kara in last nine words]]
# utterance2: A: And I said no &Kara you have to do what’s right for &Kara.
#
# ground_truth: Event1: And what's right for Kara will be right for David
#
# prediction: Event1: What's right for Kara will be right for David
# similarity score: 0.9856
# ------------------------------
#
# [+] Sentence:Events: A: I wouldn’t I w-, I you know what I could never be with someone who didn’t love me.
# Context:
# utterance1: A: oh well I don’t want him to not know his daddy. [[imitating Kara]]
# utterance2: A: {breath} Why?
#
# ground_truth: Event1: A could never be with someone who didn't love A
# Event2: Someone didn't love A
#
# prediction: Event1: A could never be with someone who didn't love A Event2: A could never be with someone who didn't love A Event3: A could never be with someone who didn't love A
# similarity score: 0.9329
# ------------------------------
#
# [+] Sentence:Events: B: Hell no.
# Context:
# utterance1: A: I wouldn’t I w-, I you know what I could never be with someone who didn’t love me.
# utterance2: A: Could you?
#
# ground_truth: Event1: B says Hell no.
#
# prediction: Event1: B says Hell no.
# similarity score: 1.0
# ------------------------------
#
# [-] Sentence:Events: A: I don’t get that. Anyway so I spouted my mouth off
# Context:
# utterance1: B: Hell no.
# utterance2: A: I don’t get that.
#
# ground_truth: Event1: A spouted A's mouth off
#
# prediction: Event1: A doesn't get the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part of the sexy part
# similarity score: 0.179
# ------------------------------
#
# [+] Sentence:Events: A: yeah.
# Context:
# utterance1: A: &Jennings.
# utterance2: B: You talking about mom and dad? {laugh}
#
# ground_truth: Event1: A says yeah.
#
# prediction: Event1: A says yeah.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: A: {breath} Well then the following weekend was father’s day.
# Context:
# utterance1: A: So I think, I think I did that on purpose.
# utterance2: B: Good for you.
#
# ground_truth: Event1: Then the following weekend was father's day
#
# prediction: Event1: The following weekend was father's day
# similarity score: 0.9829
# ------------------------------
#
# [+] Sentence:Events: A: And you want to know something?
# Context:
# utterance1: A: He said no she didn’t come. She %uh she didn’t like the last two conversations that she had with you. She %uh doesn’t, didn’t like what you s- you had to say to her.
# utterance2: B: So they still backing her.
#
# ground_truth: Event1: A asks B if B wants to know somehting
# Event2: B wants to know somehting
#
# prediction: Event1: A asks B if B wants to know something
# similarity score: 0.9014
# ------------------------------
#
# [+] Sentence:Events: A: You would’ve been in that god damn car.
# Context:
# utterance1: B: Say god damn we don’t want to hear no fucking shit. Let’s go.
# utterance2: A: [background noise] Whether you’re thirty-six or twenty-six it don’t matter.
#
# ground_truth: Event1: B would have been in that god damn car
#
# prediction: Event1: B would've been in that god damn car Event2: B would've been in that god damn car
# similarity score: 0.9493
# ------------------------------
#
# [+] Sentence:Events: B: I know that and I mean i- i- you get blamed, you still get blamed for shit and, and lectured about shit that happens when you’re a kid or, or, or whatever and all that I mean.
# Context:
# utterance1: A: But it’s never their fault.
# utterance2: A: It’s never for anything that they’ve done.
#
# ground_truth: Event1: One gets blamed for shit
# Event2: One gets lectured about shit that happens when one is a kid
# Event3: Shit happens when one is a kid
#
# prediction: Event1: B knows that one gets blamed Event2: One still gets blamed for shit Event3: One is lectured about shit that happens when one is a kid Event4: One is lectured about shit that happens when one is a kid Event5: One is lectured about shit that happens when one is a kid
# similarity score: 0.9344
# ------------------------------
#
# [+] Sentence:Events: A: [background noise] Because I can’t have that twenty-four hour {breath} bitching and negative. I can’t. I can’t live like that.
# Context:
# utterance1: A: And he goes {breath} well then we’ll drive to &Omaha and pick up sh- %um &Ryan {breath} and, and then %uh we’ll bring him back {breath} and then we’ll %uh bring him back home to &Omaha.  And I said {breath}
# utterance2: A: oh so you’re not and the whole thing is that I won’t let them stay in my house anymore.
#
# ground_truth: Event1: A can't have that twenty-four hour bitching and negative
# Event2: A can't live with twenty-four hour bitching
#
# prediction: Event1: A can't have that twenty-four hour bitching and negative Event2: A can't live like that Event3: A can't live like that
# similarity score: 0.9167
# ------------------------------
#
# [+] Sentence:Events: B: mhm.
# Context:
# utterance1: A: [background noise] Because I can’t have that twenty-four hour {breath} bitching and negative. I can’t. I can’t live like that.
# utterance2: A: You know what I’m saying?
#
# ground_truth: Event1: B says mhm.
#
# prediction: Event1: B says mhm.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: A: {sniff} And I said goodbye dad.
# Context:
# utterance1: A: No you just don’t un- [[mocking imitation]] I said no dad. I think it’s you don’t understand. You don’t understand how you affect my family.  You and mom.
# utterance2: A: And and more importantly how you affect me. {breath} And he said that’s your problem. You think too much about yourself. [[imitating father in previous nine words]]
#
# ground_truth: Event1: And A said "goodbye dad"
#
# prediction: Event1: A said goodbye to dad
# similarity score: 0.9628
# ------------------------------
#
# [+] Sentence:Events: A: I said I hope that my, my sons never treat one another like this.
# Context:
# utterance1: A: Dad [distortion] You know what I said to dad when he met me at the %um when he came up to our door and said {breath} &Kara’s not coming cause she doesn’t like y- you know what I said to him
# utterance2: B: What?
#
# ground_truth: Event1: A said A hopes that A's sons never treat one another like A and B's mom and dad treat A
# Event2: A hopes that A's sons never treat one another like A and B's mom and dad treat A
# Event3: A's sons never treat one another like A and B's mom and dad treat A
#
# prediction: Event1: A said A hopes that A's and B's sons never treat one another like this Event2: A's and B's sons never treat one another like this
# similarity score: 0.9105
# ------------------------------
#
#
#
# SBERT Score Cosine Similarity Average on test set with 146 samples: 0.7256130136986298

# %% [markdown]
# ## 4. Run Inference

# %%
TEXT = "Events: A: What kind of car do you have now?"
inputs = tokenizer.encode_plus(TEXT, padding='max_length', max_length=512, return_tensors='pt').to('cuda')
outputs = model.generate(inputs['input_ids'], attention_mask=inputs['attention_mask'], max_length=150, num_beams=4, early_stopping=True)
prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(f"Events Extracted with Flan-T5-Base LLM:\n{prediction}")
# Out:
# Events Extracted with Flan-T5-Base LLM:
# Event1: A asks A what kind of car A has now Event2: A has now a car

# %%
from random import randrange

sample = dataset['test'][randrange(len(dataset["test"]))]
print(f"Sentence: {sample['Sentence']}\nGround truth:\n{sample['Events']}\n---------------")
TEXT = "Events: " + sample['Sentence']
inputs = tokenizer.encode_plus(TEXT, padding='max_length', max_length=512, return_tensors='pt').to('cuda')
outputs = model.generate(inputs['input_ids'], attention_mask=inputs['attention_mask'], max_length=150, num_beams=4, early_stopping=True)
prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Events Extracted with Flan-T5-Base LLM:\n{prediction}")
calculate_rouge_score(sample['Events'], prediction)
# Out:
# Sentence: A: Right. When do you sleep then?
# Context:
# utterance1: A: What else is going on? You’re busy with work and
# utterance2: B: yeah. I work ten at night to six in the morning. &Bo &Bo’s happy because %uh he don’t have to go back to day care.
#
# Ground truth:
# Event1: A asks B when B sleeps then
# Event2: B sleeps
#
# ---------------
# Events Extracted with Flan-T5-Base LLM:
# Event1: A asks B when do B and Bo sleep Event2: B and Bo sleep
# Score(precision=0.6666666666666666, recall=0.9090909090909091, fmeasure=0.7692307692307692)

# %% [markdown]
# ### Run This Block just for show all results on Test set

# %%
for sample in dataset['test']:
  print(f"Sentence: {sample['Sentence']}\nGround truth:\n{sample['Events']}\n")
  TEXT = "Events: " + sample['Sentence']
  inputs = tokenizer.encode_plus(TEXT, padding='max_length', max_length=512, return_tensors='pt').to('cuda')
  outputs = model.generate(inputs['input_ids'], attention_mask=inputs['attention_mask'], max_length=150, num_beams=4, early_stopping=True)
  prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
  print(f"Events Extracted with Flan-T5-Base LLM:\n{prediction}")
  calculate_rouge_score(sample['Events'], prediction)
  print("-"*80)

# %% [markdown]
# ## Save Pretrained Model

# %%
save_directory = "/content/drive/MyDrive/Common Ground Docs/Models/FlanT5_Event_Extraction_3_to_1_2previous"
tokenizer.save_pretrained(save_directory)
model.save_pretrained(save_directory)

# %% [markdown]
# ### load Model and Test pretrained model

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained(save_directory)
pretrained_model = AutoModelForSeq2SeqLM.from_pretrained(save_directory)

# %%
pretrained_model.to('cuda')

# %% [markdown]
# Rouge

# %%
samples_number = len(dataset['test'])

SUM = 0
for sample in dataset['test']:
  TEXT = "Events: " + sample['Sentence']
  ground_truth = sample['Events']
  inputs = tokenizer(TEXT, return_tensors="pt").to('cuda')
  outputs = pretrained_model.generate(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"], max_length=512)
  prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
  rouge = calculate_rouge_score(ground_truth, prediction)
  SUM += rouge[2] # rougeL fmeasure

rouge_avg = SUM/samples_number
print(f"\nRougeL average on test set with {samples_number} samples: {rouge_avg}")
# Out:
# RougeL average on test set with 47 samples: 0.5899351297618687

# %% [markdown]
# SBERT

# %%
samples_number = len(dataset['test'])

SUM = 0
for sample in dataset['test']:
  TEXT = "Events: " + sample['Sentence']
  ground_truth = sample['Events']
  inputs = tokenizer(TEXT, return_tensors="pt").to('cuda')
  outputs = model.generate(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"], max_length=512)
  prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
  sbert_score = calculate_sbert_score(ground_truth, prediction)
  SUM += sbert_score

  if sbert_score<0.2: print(f"\n[-] Sentence:{TEXT} \nground_truth: {ground_truth} \nprediction: {prediction} \nsimilarity score: {sbert_score}", '\n------------------------------')
  if sbert_score>0.9: print(f"\n[+] Sentence:{TEXT} \nground_truth: {ground_truth} \nprediction: {prediction} \nsimilarity score: {sbert_score}", '\n------------------------------')

sbert_score_avg = SUM/samples_number
print(f"\n\n\nSBERT Score Cosine Similarity Average on test set with {samples_number} samples: {sbert_score_avg}")
# Out:
# [+] Sentence:Events: A: %um but although they solicit, they’re trying to solicit more throughout the, throughout the globe instead of just &Japan
# ground_truth: Event1: Although the company solicits, the company is trying to solicit more throughout the globe instead of just Japan
# Event2: The company solicits
# Event3: The company is trying to solicit more throughout the globe instead of just Japan
#
# prediction: Event1: Although they solicit, they are trying to solicit more throughout the globe instead of just Japan Event2: They solicit more throughout the globe instead of just Japan
# similarity score: 0.914
# ------------------------------
#
# [+] Sentence:Events: A: although they’ve had most interest in &Japan.
# ground_truth: Event1: The company have had most interest in Japan
#
# prediction: Event1: Although they have had most interest in Japan
# similarity score: 0.9059
# ------------------------------
#
# [+] Sentence:Events: A: And I teach probably two classes and then do administrative work to make connections for these people to have tours
# ground_truth: Event1: A teaches two classes
# Event2: A does administrative work to make connections for the company representatives to have tours
# Event3: A does administrative work
# Event4: A makes connections for the company representative to have tours
#
# prediction: Event1: A teaches probably two classes and then does administrative work to make connections for these people to have tours Event2: A makes connections for these people to have tours
# similarity score: 0.9168
# ------------------------------
#
# [+] Sentence:Events: A: And you know and I do a little teaching for them too.
# ground_truth: Event1: A does a little teaching for A's students too
#
# prediction: Event1: A does a little teaching for them
# similarity score: 0.9036
# ------------------------------
#
# [+] Sentence:Events: B: okay. What classes did you teach at (( )) that would be related?
# ground_truth: Event1: B asks A what classes B taught that would be related
# Event2: B taught classes that would be related
#
# prediction: Event1: B asks A what classes A taught at Event2: A taught at Event3: A would be related to A's class
# similarity score: 0.9395
# ------------------------------
#
# [+] Sentence:Events: A: I taught business English.
# ground_truth: Event1: A taught business English
#
# prediction: Event1: A taught business English
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: A: I taught listening. I taught integrated skills and g- beginning grammar.
# ground_truth: Event1: A taught listening
# Event2: A taught integrated skills and beginning grammar
#
# prediction: Event1: A taught listening Event2: A taught integrated skills and g- beginning grammar
# similarity score: 0.9585
# ------------------------------
#
# [+] Sentence:Events: A: I had a dream this morning about,
# ground_truth: Event1: A had a dream this morning
#
# prediction: Event1: A had a dream this morning about
# similarity score: 0.9913
# ------------------------------
#
# [+] Sentence:Events: B: %eh w- listen. Was it difficult coming back, going back to the &U &S?
# ground_truth: Event1: B asks A if going back to the US was difficult
# Event2: Going back to the US was difficult
#
# prediction: Event1: B asks A if it was difficult coming back, going back to the U & S Event2: It was difficult coming back, going back to the U & S
# similarity score: 0.9443
# ------------------------------
#
# [+] Sentence:Events: A: yeah.
# ground_truth: Event1: A says yeah.
#
# prediction: Event1: A says yeah.
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: A: I didn’t really want to see anybody for a while.
# ground_truth: Event1: A didn’t really want to see anybody for a while
#
# prediction: Event1: A didn't really want to see anybody for a while Event2: A didn't really want to see anybody for a while
# similarity score: 0.9045
# ------------------------------
#
# [+] Sentence:Events: A: &Blimpie’s is the sandwich place (( )) {laugh}
# ground_truth: Event1: Blimpie's is the sandwich place
#
# prediction: Event1: Blimpie's is the sandwich place
# similarity score: 1.0
# ------------------------------
#
# [+] Sentence:Events: B: I just went back and I decided people are a bit too cheery in the &U &S.
# ground_truth: Event1: B just went back
# Event2: B decided people are a bit too cheery in the US
# Event3: People are a bit too cheery in the US
#
# prediction: Event1: B just went back and B decided people are a bit too cheery in the U.S. Event2: People are a bit too cheery in the U.S.
# similarity score: 0.9704
# ------------------------------
#
# [+] Sentence:Events: B: you know I had time off and %um
# ground_truth: Event1: B had time off
#
# prediction: Event1: B had time off Event2: B had time off
# similarity score: 0.9092
# ------------------------------
#
# [+] Sentence:Events: A: you know I was going to tell you this thing that I got. &Tom found this for me about this freebie experiment thing where you can do this and you can talk.
# ground_truth: Event1: A was going to tell B this thing that A got
# Event2: A told B this thing that A got
# Event3: A got this thing
# Event4: Tom found this for A about this freebie experiment thing where one can do this and one can talk
# Event5: Tom found this freebie experiment for A
# Event6: One can do this freebie experiment
# Event7: One can talk
#
# prediction: Event1: A was going to tell Tom this thing that A got Event2: Tom found this for A about this freebie experiment thing where one can do this and talk Event3: A can talk Event4: A got this freebie experiment thing
# similarity score: 0.9394
# ------------------------------
#
#
#
# SBERT Score Cosine Similarity Average on test set with 47 samples: 0.7807638297872341
